# %% [markdown]
# AIML LAB EXTERNAL (2024 – 25)
# SET – 2 (Logistic Regression)
# 1. Implement logistic regression on a binary classification dataset.
# 2. Calculate and interpret the confusion matrix.
# 3. Evaluate the model using accuracy and F1-score.
# 4. Visualize the decision boundary of the logistic regression model.
# 5. Implement regularization (L1 or L2) and evaluate the model performance.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, classification_report

# %%
data1 = pd.read_csv('/content/bd_students_per.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#         id         full_name  age  gender location  family_size  \
# 0        2        Avi Biswas   16    Male    Urban            6
# 1        3   Taslima Sultana   18  Female    Rural            6
# 2        4  Md Adilur Rahman   15    Male    Rural            4
# 3        5       Saleh Ahmed   16    Male    Rural            6
# 4        6         Din Islam   17    Male    Urban            5
# ...    ...               ...  ...     ...      ...          ...
# 8607  8609      Elina Khanam   17  Female     City            5
# 8608  8610       Sadiq Ghosh   16    Male     City            2
# 8609  8611        Arman Amin   18    Male     City            3
# 8610  8612     Tawhidul Saif   15    Male    Urban            5
# 8611  8613        Naimul Sen   18    Male    Urban            3
#
#      mother_education father_education mother_job father_job  ... tutoring  \
# 0                 SSC              HSC         No         No  ...      Yes
# ...

# %%
df1['target'] = (df1['stu_group'] == 'Science').astype(int)


print("Class Distribution:")
print(df1['target'].value_counts())


selected_features = ['age', 'family_size', 'attendance', 'english', 'math', 'science']
X = df1[selected_features]
y = df1['target']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# Class Distribution:
# target
# 0    8258
# 1     354
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred, target_names=["Not Science", "Science"], zero_division=0)

# %%
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[2464    0]
#  [ 120    0]]

# %%
print("\nConfusion Matrix Breakdown:")
print(f"True Negatives: {conf_matrix[0, 0]}")
print(f"False Positives: {conf_matrix[0, 1]}")
print(f"False Negatives: {conf_matrix[1, 0]}")
print(f"True Positives: {conf_matrix[1, 1]}")
# Out:
# Confusion Matrix Breakdown:
# True Negatives: 2464
# False Positives: 0
# False Negatives: 120
# True Positives: 0

# %%
print(f"\nAccuracy: {accuracy:.2f} - The proportion of total predictions that were correct.")
print(f"F1-Score: {f1:.2f} - The harmonic mean of precision and recall.")
# Out:
# Accuracy: 0.95 - The proportion of total predictions that were correct.
# F1-Score: 0.00 - The harmonic mean of precision and recall.

# %%
print("\nDetailed Classification Report:")
print(classification_rep)
# Out:
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#  Not Science       0.95      1.00      0.98      2464
#      Science       0.00      0.00      0.00       120
#
#     accuracy                           0.95      2584
#    macro avg       0.48      0.50      0.49      2584
# weighted avg       0.91      0.95      0.93      2584
